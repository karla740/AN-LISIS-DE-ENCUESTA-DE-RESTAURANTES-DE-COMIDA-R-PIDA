# %% [markdown]
# # Análisis de Encuesta: Restaurantes de Comida Rápida
# **Análisis de Encuesta**
#
# ## Propósito del Proyecto
# Este notebook presenta los resultados del análisis del comportamiento de 10,000 clientes de una empresa del sector de alimentos. El objetivo es identificar áreas de mejora en el servicio, productos y la experiencia general utilizando estructuras de datos anidadas en Python.
#
# ---
# ## Configuración Inicial y Carga de Datos
# A continuación, importamos nuestros módulos de lógica (`lectura_datos.py` y `reportes.py`) y cargamos la base de datos de encuestas.

# %%
# Activar la recarga automática para no tener que reiniciar el notebook 
# si alguien modifica 'reportes.py' o 'lectura_datos.py' en GitHub
# %load_ext autoreload
# %autoreload 2

# Importar los módulos que crearon
import lectura_datos
import reportes

# Cargar los datos usando la función de lectura_datos.py
ruta = "encuesta_restaurante.csv"
datos_encuesta = lectura_datos.cargar_datos(ruta)

print(f"✅ ¡Datos cargados exitosamente! Se procesaron {len(datos_encuesta)} encuestas.")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ✅ ¡Datos cargados exitosamente! Se procesaron 10000 encuestas.
